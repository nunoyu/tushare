# %%
import tushare as ts
import pandas as pd

# %%
df = ts.get_tick_data('002743', date='2016-10-28')

# %%
# df.tail(10)

# %%
df['time'] = '2016-10-28 ' + df['time'] #时间前面加上日期，不用for，整列统一加上
df['time'] = pd.to_datetime(df['time']) #将整列从文本变成时间格式

# %% [markdown]
# ## 将转换格式后的时间列设置为index

# %%
df = df.set_index('time') # 将转换格式后的时间列设置为index

# %%
df.tail(10)
# Out:
#                      price change  volume  amount type
# time
# 2016-10-28 09:30:24  17.55  -0.03       5    8775   卖盘
# 2016-10-28 09:30:21  17.58   0.03       7   12305   买盘
# 2016-10-28 09:30:18  17.55  -0.03      40   70200   卖盘
# 2016-10-28 09:30:15  17.58   0.02      21   36918   买盘
# 2016-10-28 09:30:12  17.56     --       5    8780   卖盘
# 2016-10-28 09:30:09  17.56     --       1    1755   卖盘
# 2016-10-28 09:30:06  17.56   0.01      33   57947  中性盘
# 2016-10-28 09:30:03  17.55   0.04     293  514215   买盘
# 2016-10-28 09:30:00  17.51     --       0       0  中性盘
# 2016-10-28 09:25:03  17.51  17.51     261  457011   买盘

# %%
price_df = df['price'].resample('1min').ohlc() #新建一个价格dataframe,然后自动将分笔数据变成1分钟数据，还加上了时间列

# %%
price_df = price_df.dropna() #删除空值

# %%
price_df.head(10)
# Out:
#                       open   high    low  close
# time
# 2016-10-28 09:25:00  17.51  17.51  17.51  17.51
# 2016-10-28 09:30:00  17.51  17.58  17.51  17.55
# 2016-10-28 09:31:00  17.54  17.55  17.51  17.52
# 2016-10-28 09:32:00  17.49  17.49  17.48  17.48
# 2016-10-28 09:33:00  17.46  17.46  17.40  17.40
# 2016-10-28 09:34:00  17.40  17.48  17.40  17.45
# 2016-10-28 09:35:00  17.48  17.53  17.48  17.53
# 2016-10-28 09:36:00  17.53  17.53  17.50  17.50
# 2016-10-28 09:37:00  17.50  17.50  17.43  17.43
# 2016-10-28 09:38:00  17.43  17.43  17.41  17.41

# %%
vols = df['volume'].resample('1min').sum() #从分笔数据计算分钟数据成交量

# %%
vols = vols.dropna() #去掉空值

# %%
vol_df = pd.DataFrame(vols, columns=['volume'])

# %%
amounts = df['amount'].resample('1min').sum()

# %%
amounts = amounts.dropna()

# %%
amount_df = pd.DataFrame(amounts, columns=['amount'])

# %% [markdown]
# # 根据index对几个dataframe进行合并，这里最重要。

# %%
newdf = price_df.merge(vol_df, left_index=True, 
                       right_index=True).merge(amount_df, 
                                               left_index=True, 
                                               right_index=True)

# %%
newdf.tail(20)
# Out:
#                       open   high    low  close  volume     amount
# time
# 2016-10-28 14:39:00  17.56  17.58  17.54  17.57   497.0   872756.0
# 2016-10-28 14:40:00  17.57  17.60  17.55  17.55   552.0   969622.0
# 2016-10-28 14:41:00  17.55  17.55  17.53  17.53   183.0   320973.0
# 2016-10-28 14:42:00  17.53  17.55  17.52  17.54   178.0   312139.0
# 2016-10-28 14:43:00  17.54  17.56  17.53  17.55   361.0   633280.0
# 2016-10-28 14:44:00  17.55  17.59  17.55  17.59   266.0   467765.0
